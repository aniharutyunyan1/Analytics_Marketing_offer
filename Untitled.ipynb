# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.discrete.discrete_model import Logit
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
import statsmodels.tools as sm
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, recall_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV,cross_val_score
import scikitplot as skplt 
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-4431f35e8e26> in <module>
#      12 from sklearn.ensemble import RandomForestClassifier
#      13 from sklearn.model_selection import GridSearchCV,cross_val_score
# ---> 14 import scikitplot as skplt
#      15 import warnings
#      16 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'scikitplot'

# %%
url="https://raw.githubusercontent.com/aniharutyunyan1/Bus1234/master/CRA_client_data%202.csv"
data=pd.read_csv(url)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58188 entries, 0 to 58187
# Columns: 143 entries, STATE_CD to CLIENT_ID
# dtypes: float64(3), int64(128), object(12)
# memory usage: 60.8+ MB

# %%
data.describe()
# Out:
#              ZIP_CD         DEM05  DEM10         SCR16  BKRPT_RCV_SCORE_VALUE  \
# count  58188.000000  58188.000000    0.0  58188.000000           58188.000000
# mean   48503.835499     10.509710    NaN    629.502028             285.474067
# std    30823.041620     10.496808    NaN     59.153490             161.227238
# min     1001.000000      0.000000    NaN    391.000000               1.000000
# 25%    21043.000000      2.000000    NaN    598.000000             171.750000
# 50%    40475.000000      7.000000    NaN    642.000000             294.000000
# 75%    78213.000000     16.000000    NaN    675.000000             399.000000
# max    99901.000000     69.000000    NaN    720.000000             866.000000
#
#               SCR02  SMARTV40_AAL01  SMARTV40_AAL02  SMARTV40_AAL06  \
# count  58188.000000    58188.000000    58188.000000    58188.000000
# mean     750.428594       23.693373       11.692222       12.504193
# std      242.883966       12.203782        6.121272        6.397817
# min      179.000000        2.000000        2.000000        1.000000
# 25%      659.000000       15.000000        7.000000        8.000000
# 50%      743.000000       22.000000       10.000000       11.000000
# 75%      828.000000       30.000000       15.000000       16.000000
# max     9999.000000      155.000000       67.000000       73.000000
#
#        SMARTV40_AAL07  ...      BRC5231T      BRC5530T      BRC5531T  \
# count    58188.000000  ...  5.818800e+04  5.818800e+04  5.818800e+04
# mean        10.904998  ...  2.437413e+05  2.457344e+05  2.456153e+05
# std          5.800581  ...  1.550949e+07  1.550946e+07  1.550946e+07
# min          1.000000  ...  0.000000e+00  2.050000e+02  2.050000e+02
# 25%          7.000000  ...  1.675000e+03  2.855000e+03  2.784000e+03
# 50%         10.000000  ...  2.509000e+03  4.271000e+03  4.165000e+03
# 75%         14.000000  ...  3.854000e+03  6.419000e+03  6.264000e+03
# max         66.000000  ...  1.000000e+09  1.000000e+09  1.000000e+09
#
#            BRC8131T         XFC06         XFC07  DECILE        EXP_ID  \
# count  58188.000000  58188.000000  58188.000000     0.0  58188.000000
# mean       3.441380      1.743040      0.155255     NaN     80.136179
# std        5.929593      2.694051      0.591608     NaN      9.166588
# min        0.000000      0.000000      0.000000     NaN     68.000000
# 25%        0.000000      0.000000      0.000000     NaN     72.000000
# 50%        1.000000      1.000000      0.000000     NaN     76.000000
# 75%        4.000000      2.000000      0.000000     NaN     88.000000
# max       98.000000     54.000000     28.000000     NaN     96.000000
#
#        RESPONSE_FLAG  CLIENT_ID
# count   58188.000000    58188.0
# mean        0.166667       53.0
# std         0.372681        0.0
# min         0.000000       53.0
# 25%         0.000000       53.0
# 50%         0.000000       53.0
# 75%         0.000000       53.0
# max         1.000000       53.0
#
# [8 rows x 131 columns]

# %%
data.head()
# Out:
#   STATE_CD  ZIP_CD SEGMENT_CODE DEM03  DEM05 DEM06 DEM07 DEM08 DEM09  DEM10  \
# 0       NJ    7110            B     F     10     Y     H     I     S    NaN
# 1       MA    2359            B     M      5     Y     H     G     S    NaN
# 2       FL   33433            A     F      0     Y     P     I     A    NaN
# 3       NM   87123            A     F     12     Y     R     L     S    NaN
# 4       IN   47598            A     M      4     Y     H     D     S    NaN
#
#    ...  BRC5530T  BRC5531T  BRC8131T  XFC06  XFC07  DECILE          KEYID  \
# 0  ...     13424     13360         0      1      1     NaN  07110112PP300
# 1  ...      4560      4548         2      2      0     NaN  0235960VAC640
# 2  ...      3581      3665         3      2      0     NaN  334337170S320
# 3  ...      1127      1072         0      1      0     NaN  87123436GN635
# 4  ...      7599      7366         1      2      0     NaN  475981467L563
#
#    EXP_ID  RESPONSE_FLAG  CLIENT_ID
# 0      88            0.0         53
# 1      92            0.0         53
# 2      92            0.0         53
# 3      84            0.0         53
# 4      84            0.0         53
#
# [5 rows x 143 columns]

# %%
print("Duplicates:", data.duplicated().sum())
print("Missing values:", data.isna().sum().sum())
print("Single valued columns:", data.columns[data.nunique()==1])
# Out:
# Duplicates: 0
# Missing values: 116393
# Single valued columns: Index(['SMARTV40_APR14', 'CLIENT_ID'], dtype='object')

# %%
data.isnull().any()
# Out:
# STATE_CD         False
# ZIP_CD           False
# SEGMENT_CODE     False
# DEM03            False
# DEM05            False
#                  ...
# DECILE            True
# KEYID            False
# EXP_ID           False
# RESPONSE_FLAG    False
# CLIENT_ID        False
# Length: 143, dtype: bool

# %%
categorical_colnames=data.select_dtypes(include="object").columns
for colname in categorical_colnames:
    val_count=data[colname].value_counts()
    print(colname,"\n",val_count,"\n","\n")
    print("--------------------")
# Out:
# STATE_CD
#  CA    9008
# TX    6841
# FL    6616
# NY    5399
# NJ    3352
# PA    2771
# NC    2219
# OH    2146
# VA    2117
# MI    2010
# MD    1695
# MA    1599
# AZ    1468
# TN    1342
# IN    1189
# MO    1070
# WI     911
# NV     900
# AL     868
# KY     813
# OK     659
# AR     545
# MS     482
# HI     413
# NE     391
# NM     339
# ID     258
# AK     175
# DC     163
# SD     151
# NH     148
# MT     130
# Name: STATE_CD, dtype: int64
#
#
# --------------------
# SEGMENT_CODE
#  A    24141
# B    14802
# F     7844
# C     5776
# G     2183
# D     1244
# E     1140
# H     1058
# Name: SEGMENT_CODE, dtype: int64
#
#
# --------------------
# DEM03
#  M    27863
# F    27616
# U     2671
# B       38
# Name: DEM03, dtype: int64
#
#
# --------------------
# DEM06
#  U    26417
# Y    23013
# N     8758
# Name: DEM06, dtype: int64
#
#
# --------------------
# DEM07
#  H    31324
# U    11318
# T     7336
# P     4790
# R     3420
# Name: DEM07, dtype: int64
#
#
# --------------------
# DEM08
#  E    11824
# F    10151
# D     6569
# G     6553
# H     4877
# C     3434
# A     2945
# B     2858
# L     2570
# I     2370
# J     2013
# K     1947
# U       60
# Name: DEM08, dtype: int64
#
#
# --------------------
# DEM09
#  S    42662
# A     8809
# U     6106
# M      510
# P      101
# Name: DEM09, dtype: int64
#
#
# --------------------
# SMARTV40_AAU19
#  0    12112
# 7     9812
# 5     5546
# 4     5259
# 6     4972
# 3     3434
# D     2625
# E     2392
# G     2257
# C     2235
# 8     2083
# F     1668
# 2     1558
# B     1394
# A      321
# H      299
# 1      196
# U       24
# 9        1
# Name: SMARTV40_AAU19, dtype: int64
#
#
# --------------------
# SMARTV40_AAU20
#  7    25080
# 0    12112
# E    10172
# 6     2571
# 5     2075
# 3      860
# 4      855
# B      839
# C      744
# A      743
# 2      731
# D      717
# 1      689
# Name: SMARTV40_AAU20, dtype: int64
#
#
# --------------------
# SMARTV40_AAU22
#  B    13215
# 0    12112
# 9     6573
# 8     4913
# 5     4132
# 4     3531
# 6     3425
# 7     3355
# 3     3197
# 2     2020
# 1     1706
# A        9
# Name: SMARTV40_AAU22, dtype: int64
#
#
# --------------------
# SMARTV40_ALE21
#  0    46054
# B     4955
# 9     1337
# 5     1065
# 8     1030
# 4      822
# 7      804
# 6      796
# 3      747
# 2      360
# 1      213
# A        5
# Name: SMARTV40_ALE21, dtype: int64
#
#
# --------------------
# KEYID
#  933116002L532    2
# 47987700WB500    2
# 9261016SAW230    2
# 440775789W426    2
# 10970468CS123    2
#                 ..
# 891317350C621    1
# 0108579MOY150    1
# 946081585C400    1
# 488542205B650    1
# 0740549CHS400    1
# Name: KEYID, Length: 58019, dtype: int64
#
#
# --------------------

# %%
drops = ["SMARTV40_APR14","CLIENT_ID","SEGMENT_CODE","KEYID","XFC06","XFC07","DECILE","DEM10"]
data = data.drop(drops,axis=1)

# %%
plt.figure(figsize=(9,5))
sns.countplot(data.RESPONSE_FLAG)
plt.title("RESPONSE")
plt.show()

# %%
plt.figure(figsize=(18,18))
sns.heatmap(data.corr().abs().round(2),annot=True, cmap = "coolwarm")
plt.show()

# %%
drawheatmap(df_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9a9d9f4b2fe6> in <module>
# ----> 1 drawheatmap(df_clean)
#       2
#
# NameError: name 'df_clean' is not defined

# %%
data.RESPONSE_FLAG.value_counts(normalize=True).mul(100).rename("RESPONSE FLAG percentage")
# Out:
# 0.0    83.333333
# 1.0    16.666667
# Name: RESPONSE FLAG percentage, dtype: float64

# %%
print("Duplicates:", data.duplicated().sum())
print("Missing values:", data.isna().sum().sum())
print("Single valued columns:", data.columns[data.nunique()==1])
# Out:
# Duplicates: 0
# Missing values: 17
# Single valued columns: Index([], dtype='object')

# %%
numeric_colnames=data.dtypes[data.dtypes=="O"].index.tolist()
rates_list=[]
for colname in numeric_colnames:
    rates=data.groupby(colname)["RESPONSE_FLAG"].value_counts(normalize=True).rename("percentage").mul(100).reset_index()
    rates_list.append(rates)

# %%
rates_list[0]
# Out:
#    STATE_CD  RESPONSE_FLAG  percentage
# 0        AK            0.0   85.142857
# 1        AK            1.0   14.857143
# 2        AL            0.0   84.447005
# 3        AL            1.0   15.552995
# 4        AR            0.0   81.834862
# ..      ...            ...         ...
# 59       TX            1.0   15.640988
# 60       VA            0.0   86.395843
# 61       VA            1.0   13.604157
# 62       WI            0.0   82.656422
# 63       WI            1.0   17.343578
#
# [64 rows x 3 columns]

# %%
data=pd.get_dummies(data,drop_first=True)

X=data.drop('RESPONSE_FLAG', axis=1)
Y=data.RESPONSE_FLAG

# %%
X=sm.add_constant(X)

# %%
X0, X1, Y0, Y1=train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
def make_tree(model):
    tree_0=model
    tree_0.fit(X0,Y0)
    Y0_0_proba = tree_0.predict_proba(X0)[:,1] 
    Y1_0_proba = tree_0.predict_proba(X1)[:,1] 

    Y0_0_class = np.where(Y0_0_proba>0.5,1,0) 
    Y1_0_class = np.where(Y1_0_proba>0.5,1,0) 

    print("Train ROC AUC by tree_0:",roc_auc_score(Y0,Y0_0_proba))
    print("Test ROC AUC by tree_0:",roc_auc_score(Y1,Y1_0_proba))

    print("\n")

    print("Train Recall by tree_0:",recall_score(Y0,Y0_0_class))
    print("Test Recall by tree_0:",recall_score(Y1,Y1_0_class))

# %%
make_tree(DecisionTreeClassifier(random_state=42))
# Out:
# Train ROC AUC by tree_0: 1.0
# Test ROC AUC by tree_0: 0.5539230824140857
#
#
# Train Recall by tree_0: 1.0
# Test Recall by tree_0: 0.2694489465153971

# %%
#change the parameters
make_tree(DecisionTreeClassifier(max_depth=7,class_weight="balanced",random_state=42))
# Out:
# Train ROC AUC by tree_0: 0.7387837461001652
# Test ROC AUC by tree_0: 0.6899641682263834
#
#
# Train Recall by tree_0: 0.7683264177040111
# Test Recall by tree_0: 0.715964343598055

# %%
make_tree(DecisionTreeClassifier(min_samples_leaf=85,random_state=42))
# Out:
# Train ROC AUC by tree_0: 0.7949784128510099
# Test ROC AUC by tree_0: 0.6791074776092507
#
#
# Train Recall by tree_0: 0.10760719225449517
# Test Recall by tree_0: 0.08792544570502431

# %%
make_tree(DecisionTreeClassifier(max_depth=7,min_samples_leaf=85,random_state=42))
# Out:
# Train ROC AUC by tree_0: 0.7312012754493773
# Test ROC AUC by tree_0: 0.694631929478851
#
#
# Train Recall by tree_0: 0.06251728907330567
# Test Recall by tree_0: 0.053079416531604535

# %%
#BEST Hyperparameters
tree_best = DecisionTreeClassifier(max_depth=7,min_samples_leaf=85,random_state=42)
tree_best.fit(X0,Y0)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=7,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=85, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
pd.DataFrame(data=tree_best.feature_importances_,index=X0.columns)
# Out:
#                               0
# const                  0.000000
# ZIP_CD                 0.013337
# DEM05                  0.000000
# SCR16                  0.003667
# BKRPT_RCV_SCORE_VALUE  0.002796
# ...                         ...
# SMARTV40_ALE21_7       0.000000
# SMARTV40_ALE21_8       0.000000
# SMARTV40_ALE21_9       0.000000
# SMARTV40_ALE21_A       0.000000
# SMARTV40_ALE21_B       0.000000
#
# [233 rows x 1 columns]

# %%
tree_final = DecisionTreeClassifier(max_depth=7,min_samples_leaf=85,random_state=42)
tree_final.fit(X0[["ZIP_CD","SCR16","BKRPT_RCV_SCORE_VALUE","average_montly_hours","time_spend_company"]],Y0)

Y0_best_proba = tree_final.predict_proba(X0[["satisfaction_level","last_evaluation","number_project","average_montly_hours","time_spend_company"]])[:,1]
Y1_best_proba = tree_final.predict_proba(X1[["satisfaction_level","last_evaluation","number_project","average_montly_hours","time_spend_company"]])[:,1]

Y0_best_class = np.where(Y0_best_proba>0.5,1,0)
Y1_best_class = np.where(Y1_best_proba>0.5,1,0)

print("Train ROCAUC:",roc_auc_score(Y0,Y0_best_proba))
print("Test ROCAUC:",roc_auc_score(Y1,Y1_best_proba))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-22270e4e8872> in <module>
#       1 tree_final = DecisionTreeClassifier(max_depth=7,min_samples_leaf=85,random_state=42)
# ----> 2 tree_final.fit(X0[["satisfaction_level","last_evaluation","number_project","average_montly_hours","time_spend_company"]],Y0)
#       3
#       4 Y0_best_proba = tree_final.predict_proba(X0[["satisfaction_level","last_evaluation","number_project","average_montly_hours","time_spend_company"]])[:,1]
#       5 Y1_best_proba = tree_final.predict_proba(X1[["satisfaction_level","last_evaluation","number_project","average_montly_hours","time_spend_company"]])[:,1]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['satisfaction_level', 'last_evaluation', 'number_project',\n       'average_montly_hours', 'time_spend_company'],\n      dtype='object')] are in the [columns]"

# %%
plt.figure(figsize=(30,30))
plot_tree(tree_final,filled=True,feature_names=X0.columns)
plt.show()
